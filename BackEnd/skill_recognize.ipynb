# %%
import pandas as pd                 
working = pd.read_csv('dataset_token.csv')
display(working)
# Out:
#                   Job Id     Experience Qualifications Salary Range  \
# 0       1089843540111562  5 to 15 years      ['mtech']       59-99k
# 1        398454096642776  2 to 12 years        ['bca']      56-116k
# 2        481640072963533  0 to 12 years        ['phd']      61-104k
# 3        688192671473044  4 to 11 years        ['phd']       65-91k
# 4        117057806156508  1 to 12 years        ['mba']       64-87k
# ...                  ...            ...            ...          ...
# 107359  1983179143713411  3 to 12 years        ['bba']      60-128k
# 107360   669857235415970  2 to 15 years        ['mba']      59-121k
# 107361  2722200185343244  0 to 11 years        ['mca']       59-80k
# 107362  2740245700222760   1 to 9 years        ['bba']       63-83k
# 107363  2728583024325919  0 to 13 years        ['bca']       59-98k
#
#                 location              Country      Work Type  Company Size  \
# ...

# %%
unique_skills = working['skills'].unique()
print(unique_skills)
# Out:
# ['social media platforms eg facebook twitter instagram content creation and scheduling social media analytics and insights community engagement paid social advertising'
#  'html css javascript frontend frameworks eg react angular user experience ux'
#  'quality control processes and methodologies statistical process control spc root cause analysis and corrective action quality management systems eg iso 9001 compliance and regulatory knowledge'
#  'wireless network design and architecture wifi standards and protocols rf radio frequency planning and optimization wireless security protocols troubleshooting wireless network issues'
#  'event planning conference logistics budget management vendor coordination marketing and promotion client relations'
#  'quality assurance processes testing methodologies eg manual automated bug tracking and reporting test case development regression testing'
# ...

# %%
import spacy
from spacy.training.example import Example

nlp = spacy.blank("en")

ner = nlp.add_pipe("ner")

ner.add_label("SKILL")

# Prepare training data
training_data = [
    ("social media platforms eg facebook twitter instagram content creation scheduling social media analytics insights community engagement paid social advertising",
     {"entities": [
        (53, 84, "SKILL"),  # content creation and scheduling
        (85, 120, "SKILL"),  # social media analytics and insights
        (121, 141, "SKILL"),  # community engagement
        (142, 164, "SKILL")  # paid social advertising
    ]}),
    ("html css javascript frontend frameworks eg react angular user experience ux",
     {"entities": [
        (0, 4, "SKILL"),  # html
        (5, 8, "SKILL"),  # css
        (9, 19, "SKILL"),  # javascript
        (20, 38, "SKILL"),  # frontend frameworks
        (57, 74, "SKILL")  # user experience ux
    ]}),
    ("i am proficient in python and java", {"entities": [
        (19, 25, "SKILL"),
        (30, 33, "SKILL")
    ]}),
    ("quality control processes and methodologies statistical process control (spc) root cause analysis and corrective action quality management systems (e.g., iso 9001) compliance and regulatory knowledge", {"entities": [
        (0, 43, "SKILL"),  # quality control processes and methodologies
        (44, 77, "SKILL"),  # Statistical process control (SPC)
        (78, 119, "SKILL"),  # root cause analysis and corrective action
        (120, 146, "SKILL"),  # quality management systems (e.g., ISO 9001)
        (164, 198, "SKILL")  # compliance and regulatory knowledge
    ]}),
    ("wireless network design and architecture wi-fi standards and protocols rf (radio frequency) planning and optimization wireless security protocols troubleshooting wireless network issues", {"entities": [
        (0, 40, "SKILL"),  # wireless network design and architecture
        (41, 70, "SKILL"),  # wi-fi standards and protocols
        (71, 117, "SKILL"),  # RF (Radio Frequency) planning and optimization
        (118, 145, "SKILL"),  # wireless security protocols
        (146, 184, "SKILL")  # troubleshooting wireless network issues
    ]}),
    ("event planning conference logistics budget management vendor coordination marketing and promotion client relations", {"entities": [
        (0, 14, "SKILL"),  # event planning
        (15, 35, "SKILL"),  # conference logistics
        (36, 53, "SKILL"),  # budget management
        (54, 73, "SKILL"),  # vendor coordination
        (74, 97, "SKILL"),  # marketing and promotion
        (98, 113, "SKILL"),  # client relations
    ]}),
    ("quality assurance processes testing methodologies bug tracking and reporting test case development regression testing", {"entities": [
        (0, 26, "SKILL"),  # quality assurance processes
        (27, 49, "SKILL"),  # testing methodologies
        (50, 76, "SKILL"),  # bug tracking and reporting
        (77, 98, "SKILL"),  # test case development
        (99, 116, "SKILL"),  # regression testing
    ]}),
    ("teaching pedagogy classroom management curriculum development student assessment differentiated instruction", {"entities": [
        (0, 17, "SKILL"),  # teaching pedagogy
        (18, 38, "SKILL"),  # classroom management
        (39, 61, "SKILL"),  # curriculum development
        (62, 80, "SKILL"),  # student assessment
        (81, 106, "SKILL"),  # differentiated instruction
    ]}),
    ("ui design principles and best practices graphic design tools typography and color theory visual design and layout responsive design", {"entities": [
        (0, 9, "SKILL"),  # ui design principles and best practices
        (40, 60, "SKILL"),  # graphic design tools
        (61, 88, "SKILL"),  # typography and color theory
        (89, 113, "SKILL"),  # visual design and layout
        (114, 130, "SKILL"),  # responsive design
    ]}),
    ("interaction design principles user behavior and psychology wireframing and prototyping tools animation and micro-interaction design collaborative design processes", {"entities": [
        (0, 29, "SKILL"),  # interaction design principles
        (30, 58, "SKILL"),  # user behavior and psychology
        (59, 92, "SKILL"),  # wireframing and prototyping tools
        (93, 131, "SKILL"),  # animation and micro-interaction design
        (131, 161, "SKILL"),  # collaborative design processes
    ]}),
    ("wedding planning vendor coordination event management", {"entities": [
        (0, 16, "SKILL"),  # wedding planning
        (17, 36, "SKILL"),  # vendor coordination
        (37, 52, "SKILL"),  # event management
    ]}),
    ("performance testing load testing stress testing test scenarios performance monitoring benchmarking performance analysis", {"entities": [
        (0, 19, "SKILL"),  # performance testing
        (20, 32, "SKILL"),  # load testing
        (33, 47, "SKILL"),  # stress testing
        (48, 62, "SKILL"),  # test scenarios
        (63, 85, "SKILL"),  # performance monitoring
        (86, 98, "SKILL"),  # benchmarking
        (99, 118, "SKILL"),  # performance analysis
    ]}),
    ("family law divorce proceedings child custody mediation legal counseling court representation", {"entities": [
        (0, 10, "SKILL"),  # family law
        (11, 30, "SKILL"),  # divorce proceedings
        (31, 44, "SKILL"),  # child custody
        (45, 54, "SKILL"),  # mediation
        (55, 71, "SKILL"),  # legal counseling
        (72, 91, "SKILL"),  # court representation
    ]}),
    ("mechanical engineering cad software finite element analysis product development prototyping", {"entities": [
        (0, 22, "SKILL"),  # mechanical engineering
        (23, 35, "SKILL"),  # cad software
        (36, 59, "SKILL"),  # finite element analysis
        (60, 79, "SKILL"),  # product development
        (80, 90, "SKILL"),  # prototyping
    ]}),
    ("network security protocols intrusion detection and prevention security incident response firewall administration vulnerability assessment security policies and procedures log analysis ethical hacking problem-solving communication skills attention to detail", {"entities": [
        (0, 26, "SKILL"),  # network security protocols
        (27, 61, "SKILL"),  # intrusion detection and prevention
        (62, 88, "SKILL"),  # security incident response
        (89, 112, "SKILL"),  # firewall administration
        (113, 137, "SKILL"),  # vulnerability assessment
        (138, 170, "SKILL"),  # security policies and procedures
        (171, 183, "SKILL"),  # log analysis
        (184, 199, "SKILL"),  # ethical hacking
        (200, 215, "SKILL"),  # problem-solving
        (216, 236, "SKILL"),  # communication skills
        (237, 255, "SKILL"),  # attention to detail
    ]}),
    ("account management sales strategy negotiation and closing skills", {"entities": [
        (0, 18, "SKILL"),  # account management
        (19, 33, "SKILL"),  # sales strategy
        (34, 63, "SKILL"),  # negotiation and closing skills
    ]}),
    ("product branding and marketing product lifecycle management cross-functional team collaboration product launch planning market segmentation and targeting", {"entities": [
        (0, 30, "SKILL"),  # product branding and marketing
        (31, 59, "SKILL"),  # product lifecycle management
        (60, 95, "SKILL"),  # cross-functional team collaboration
        (96, 119, "SKILL"),  # product launch planning
        (120, 152, "SKILL"),  # market segmentation and targeting
    ]}),
    ("email deliverability best practices spam filter testing list hygiene blacklist monitoring email authentication deliverability metrics analysis troubleshooting deliverability issues communication skills data analysis attention to detail", {"entities": [
        (0, 12, "SKILL"),  # email deliverability best practices
        (36, 55, "SKILL"),  # spam filter testing
        (56, 68, "SKILL"),  # Lemail deliverability bes
        (69, 89, "SKILL"),  # blacklist monitoring
        (90, 110, "SKILL"),  # email authentication
        (111, 142, "SKILL"),  # deliverability metrics analysis
        (143, 180, "SKILL"),  # troubleshooting deliverability issues
        (181, 201, "SKILL"),  # Communication skills
        (202, 215, "SKILL"),  # data analysis
        (216, 234, "SKILL"),  # attention to detail
    ]}),
    ("human resources recruitment employee onboarding hris record keeping communication skills", {"entities": [
        (0, 15, "SKILL"),  # human resources
        (16, 27, "SKILL"),  # recruitment
        (28, 47, "SKILL"),  # employee onboarding
        (48, 52, "SKILL"),  # hris (hr information systems)
        (53, 67, "SKILL"),  # record keeping
        (68, 87, "SKILL"),  # communication skills
    ]}),
    ("legal administrative tasks document management calendar and docketing transcription file organization communication with clients and courts knowledge of legal terminology attention to detail multitasking computer skills", {"entities": [
        (0, 26, "SKILL"),  # legal administrative tasks
        (27, 46, "SKILL"),  # document management
        (47, 65, "SKILL"),  # calendar docketing
        (66, 78, "SKILL"),  # transcription
        (80, 97, "SKILL"),  # file organization
        (98, 131, "SKILL"),  # communication with clients courts
        (132, 162, "SKILL"),  # knowledge of legal terminology
        (163, 182, "SKILL"),  # attention to detail
        (183, 195, "SKILL"),  # multitasking
        (196, 210, "SKILL"),  # computer skills
    ]}),
    ("family medicine health assessment pediatric care chronic disease management patient education", {"entities": [
        (0, 15, "SKILL"),  # family medicine
        (16, 33, "SKILL"),  # health assessment
        (34, 48, "SKILL"),  # pediatric care
        (49, 75, "SKILL"),  # chronic disease management
        (76, 92, "SKILL"),  # patient education
    ]}),
    ("account management client relations marketing strategies campaign optimization data analysis communication skills", {"entities": [
        (0, 18, "SKILL"),  # account management
        (19, 35, "SKILL"),  # client relations
        (36, 56, "SKILL"),  # marketing strategies
        (57, 78, "SKILL"),  # campaign optimization
        (79, 92, "SKILL"),  # data analysis
        (93, 112, "SKILL"),  # communication skills
    ]}),
    ("proficiency in one or more backend programming languages (e.g., java, python, node.js, ruby) api development database management (sql or nosql) server management and deployment security best practices knowledge of web frameworks (e.g., express, django)", {"entities": [
        (27, 55, "SKILL"),  # Proficiency in one or more backend programming languages
        (93, 108, "SKILL"),  # API development
        (109, 128, "SKILL"),  # Database management
        (144, 176, "SKILL"),  # Server management and deployment
        (214, 227, "SKILL"),  # web frameworks
    ]}),
    ("supply chain logistics inventory management communication skills problem-solving vendor coordination", {"entities": [
        (0, 22, "SKILL"),  # supply chain logistics
        (23, 43, "SKILL"),  # inventory management
        (44, 64, "SKILL"),  # communication skills
        (65, 79, "SKILL"),  # problem-solving
        (80, 98, "SKILL"),  # vendor coordination
    ]}),
    ("sales training sales coaching training program development sales techniques product knowledge presentation skills", {"entities": [
        (0, 14, "SKILL"),  # sales training
        (15, 29, "SKILL"),  # sales coaching
        (30, 58, "SKILL"),  # training program development
        (59, 75, "SKILL"),  # sales techniques
        (76, 93, "SKILL"),  # product knowledge
        (94, 112, "SKILL"),  # presentation skills
    ]}),
    ("treasury management cash flow analysis risk management financial forecasting banking relations", {"entities": [
        (0, 19, "SKILL"),  # treasury management
        (20, 38, "SKILL"),  # cash flow analysis
        (39, 54, "SKILL"),  # risk management
        (55, 76, "SKILL"),  # financial forecasting
        (77, 93, "SKILL"),  # banking relations
    ]}),
    ("business tax law knowledge corporate tax planning tax compliance for businesses tax credits and incentives tax strategy development financial analysis irs regulations client relationship management communication skills tax software proficiency", {"entities": [
        (0, 26, "SKILL"),  # business tax law knowledge
        (27, 49, "SKILL"),  # corporate tax planning
        (50, 79, "SKILL"),  # tax compliance for businesses
        (80, 106, "SKILL"),  # tax credits and incentives
        (107, 131, "SKILL"),  # tax strategy development
        (132, 150, "SKILL"),  # financial analysis
        (151, 166, "SKILL"),  # irs regulations
        (167, 197, "SKILL"),  # client relationship management
        (198, 218, "SKILL"),  #communication skills
        (219, 242, "SKILL"),  # tax software proficiency
    ]}),
    ("training and development performance management learning programs employee engagement coaching and mentoring", {"entities": [
        (0, 24, "SKILL"),  # training and development
        (25, 47, "SKILL"),  # performance management
        (48, 65, "SKILL"),  # learning programs
        (66, 85, "SKILL"),  # employee engagement
        (86, 107, "SKILL"),  # coaching and mentoring
    ]}),
    ("project management leadership strategic planning team coordination budget management risk assessment", {"entities": [
        (0, 18, "SKILL"),  # project management
        (19, 29, "SKILL"),  # leadership
        (30, 48, "SKILL"),  # strategic planning
        (49, 66, "SKILL"),  # team coordination
        (67, 84, "SKILL"),  # budget management
        (85, 99, "SKILL"),  # risk assessment
    ]}),
    ("digital marketing social media management content creation seo optimization online advertising analytics", {"entities": [
        (0, 17, "SKILL"),  # digital marketing
        (18, 41, "SKILL"),  # social media management
        (42, 58, "SKILL"),  # content creation
        (59, 75, "SKILL"),  # seo optimization
        (76, 94, "SKILL"),  # online advertising
        (95, 103, "SKILL"),  # analytics
    ]}),
    ("data visualization statistical analysis machine learning predictive modeling data mining data interpretation", {"entities": [
        (0, 18, "SKILL"),  # data visualization
        (19, 39, "SKILL"),  # statistical analysis
        (40, 56, "SKILL"),  # machine learning
        (57, 76, "SKILL"),  # predictive modeling
        (77, 88, "SKILL"),  # data mining
        (89, 107, "SKILL"),  # Data interpretation
    ]}),
    ("software development agile methodology version control system debugging problem-solving code optimization", {"entities": [
        (0, 20, "SKILL"),  # software development
        (21, 38, "SKILL"),  # agile methodology
        (39, 61, "SKILL"),  # version control system
        (62, 71, "SKILL"),  # debugging
        (72, 87, "SKILL"),  # problem-solving
        (88, 104, "SKILL"),  # code optimization
    ]}),
    ("customer service conflict resolution empathy patience interpersonal skills time management", {"entities": [
        (0, 16, "SKILL"),  # customer service
        (17, 36, "SKILL"),  # conflict resolution
        (37, 44, "SKILL"),  # empathy
        (45, 53, "SKILL"),  # patience
        (54, 74, "SKILL"),  # interpersonal skills
        (75, 89, "SKILL"),  # time management
    ]}),
    ("cybersecurity network security penetration testing incident response threat detection encryption techniques", {"entities": [
        (0, 14, "SKILL"),  # cybersecurity
        (15, 30, "SKILL"),  # network security
        (31, 50, "SKILL"),  # penetration testing
        (51, 68, "SKILL"),  # incident response
        (69, 85, "SKILL"),  # threat detection
        (86, 106, "SKILL"),  # encryption techniques
    ]}),
    ("human resources recruitment performance appraisal employee relations HR policy development diversity and inclusion training", {"entities": [
        (0, 15, "SKILL"),  # human resources
        (16, 27, "SKILL"),  # recruitment
        (28, 49, "SKILL"),  # performance appraisal
        (50, 68, "SKILL"),  # employee relations
        (69, 90, "SKILL"),  # hr policy development
        (91, 122, "SKILL"),  # diversity and inclusion training
    ]}),
    ("public speaking presentation design audience engagement speech writing storytelling persuasion techniques", {"entities": [
        (0, 15, "SKILL"),  # public speaking
        (16, 35, "SKILL"),  # presentation design
        (36, 55, "SKILL"),  # audience engagement
        (55, 68, "SKILL"),  # speech writing
        (71, 83, "SKILL"),  # storytelling
        (84, 104, "SKILL"),  # persuasion techniques
    ]}),
    ("graphic design typography layout design color theory print production adobe creative suite", {"entities": [
        (0, 14, "SKILL"),  # graphic design
        (15, 25, "SKILL"),  # typography
        (26, 39, "SKILL"),  # layout design
        (40, 52, "SKILL"),  # color theory
        (53, 69, "SKILL"),  # print production
        (70, 89, "SKILL"),  # adobe Creative Suite
    ]}),
    ("event planning vendor management budgeting logistics coordination marketing promotion", {"entities": [
        (0, 14, "SKILL"),  # event planning
        (15, 32, "SKILL"),  # vendor management
        (33, 42, "SKILL"),  # budgeting
        (43, 65, "SKILL"),  # logistics coordination
        (66, 84, "SKILL"),  # marketing promotion
    ]}),
    ("content management system (CMS) WordPress Joomla Drupal content creation blog management SEO optimization", {"entities": [
        (0, 25, "SKILL"),  # content management system (CMS)
        (32, 41, "SKILL"),  # wordpress
        (42, 48, "SKILL"),  # joomla
        (48, 55, "SKILL"),  # drupal
        (56, 72, "SKILL"),  # content creation
        (73, 87, "SKILL"),  # blog management
        (89, 104, "SKILL"),  # seo optimization
    ]}),
    ("quality assurance testing bug tracking test case development automated testing regression testing", {"entities": [
        (0, 25, "SKILL"),  # quality assurance testing
        (26, 38, "SKILL"),  # bug tracking
        (39, 60, "SKILL"),  # test case development
        (61, 78, "SKILL"),  # automated testing
        (79, 96, "SKILL"),  # regression testing
    ]}),
    ("database administration sql database optimization data warehousing database security backup and recovery", {"entities": [
        (0, 23, "SKILL"),  # database administration
        (24, 27, "SKILL"),  # SQL
        (28, 49, "SKILL"),  # Database optimization
        (50, 66, "SKILL"),  # data warehousing
        (67, 84, "SKILL"),  # database security
        (85, 103, "SKILL"),  # backup and recovery
    ]}),
    ("business analysis requirement gathering process modeling data mapping stakeholder communication solution design", {"entities": [
        (0, 17, "SKILL"),  # business analysis
        (18, 39, "SKILL"),  # requirement gathering
        (40, 56, "SKILL"),  # process modeling
        (57, 69, "SKILL"),  # data mapping
        (70, 95, "SKILL"),  # stakeholder communication
        (96, 110, "SKILL"),  # solution design
    ]}),
    ("creative writing storytelling narrative structure character development dialogue crafting descriptive writing", {"entities": [
        (0, 16, "SKILL"),  # creative writing
        (17, 29, "SKILL"),  # storytelling
        (30, 49, "SKILL"),  # narrative structure
        (50, 61, "SKILL"),  # character development
        (72, 89, "SKILL"),  # dialogue crafting
        (90, 108, "SKILL"),  # descriptive writing
    ]}),
    ("project management team leadership Agile methodologies Scrum Kanban risk management stakeholder engagement", {"entities": [
        (0, 18, "SKILL"),  # project management
        (19, 34, "SKILL"),  # team leadership
        (35, 54, "SKILL"),  # agile methodologies
        (55, 60, "SKILL"),  # scrum
        (61, 67, "SKILL"),  # kanban
        (68, 83, "SKILL"),  # risk management
        (84, 105, "SKILL"),  # stakeholder engagement
    ]}),
    ("human resources recruitment employee relations performance appraisal hr policies compliance training and development", {"entities": [
        (0, 15, "SKILL"),  # human resources
        (16, 27, "SKILL"),  # recruitment
        (28, 46, "SKILL"),  # employee relations
        (47, 68, "SKILL"),  # performance appraisal
        (69, 80, "SKILL"),  # hr policies
        (81, 91, "SKILL"),  # compliance
        (92, 115, "SKILL"),  # training and development
    ]}),
    ("financial analysis budget management financial reporting forecasting risk assessment investment analysis", {"entities": [
        (0, 18, "SKILL"),  # financial analysis
        (19, 36, "SKILL"),  # budget management
        (37, 56, "SKILL"),  # financial reporting
        (57, 68, "SKILL"),  # forecasting
        (69, 84, "SKILL"),  # risk assessment
        (85, 103, "SKILL"),  # investment analysis
    ]}),
    ("software development object-oriented programming algorithms data structures version control system architecture debugging", {"entities": [
        (0, 20, "SKILL"),  # software development
        (21, 48, "SKILL"),  # object-oriented programming
        (49, 59, "SKILL"),  # algorithms
        (60, 75, "SKILL"),  # data structures
        (76, 91, "SKILL"),  # version control
        (92, 111, "SKILL"),  # system architecture
        (112, 120, "SKILL"),  # debugging
    ]}),
    ("customer service problem resolution interpersonal skills conflict management empathy patience", {"entities": [
        (0, 16, "SKILL"),  # customer service
        (17, 35, "SKILL"),  # problem resolution
        (36, 56, "SKILL"),  # interpersonal skills
        (57, 76, "SKILL"),  # conflict management
        (77, 84, "SKILL"),  # empathy
        (85, 92, "SKILL"),  # patience
    ]}),
    ("digital marketing seo SEM content marketing social media advertising email marketing analytics", {"entities": [
        (0, 17, "SKILL"),  # digital marketing
        (26, 43, "SKILL"),  # content marketing
        (44, 68, "SKILL"),  # social media advertising
        (69, 84, "SKILL"),  # email marketing
        (85, 93, "SKILL"),  # analytics
    ]}),
    ("network administration tcp/ip protocols network security firewall configuration vpn troubleshooting", {"entities": [
        (0, 22, "SKILL"),  # network administration
        (23, 39, "SKILL"),  # TCP/IP protocols
        (40, 56, "SKILL"),  # network security
        (57, 79, "SKILL"),  # firewall configuration
        (80, 98, "SKILL"),  # VPN
    ]}),
    ("data science machine learning deep learning natural language processing statistical analysis data visualization model deployment", {"entities": [
        (0, 12, "SKILL"),  # data science
        (13, 29, "SKILL"),  # machine learning
        (30, 43, "SKILL"),  # deep learning
        (44, 71, "SKILL"),  # natural language processing
        (72, 92, "SKILL"),  # statistical analysis
        (93, 111, "SKILL"),  # data visualization
        (112, 127, "SKILL"),  # model deployment
    ]}),
    ("content creation copywriting editing proofreading content management blogging social media management SEO", {"entities": [
        (0, 16, "SKILL"),  # content creation
        (17, 28, "SKILL"),  # copywriting
        (29, 36, "SKILL"),  # editing
        (37, 49, "SKILL"),  # proofreading
        (50, 68, "SKILL"),  # content management
        (69, 77, "SKILL"),  # blogging
        (80, 101, "SKILL"),  # social media management
        (102, 104, "SKILL"),  # seo
    ]}),
    ("web development html css javaScript front-end frameworks (e.g., React, Vue.js, Angular) back-end frameworks (e.g., Node.js, Django) api integration responsive design", {"entities": [
        (0, 15, "SKILL"),  # web development
        (16, 20, "SKILL"),  # html
        (21, 24, "SKILL"),  # CSS
        (25, 35, "SKILL"),  # JavaScript
        (36, 56, "SKILL"),  # Front-end frameworks
        (88, 107, "SKILL"),  # back-end frameworks
        (132, 147, "SKILL"),  # api integration
        (148, 164, "SKILL"),  # Responsive design
    ]}),
    ("project coordination time management multitasking organizational skills problem-solving collaboration", {"entities": [
        (0, 20, "SKILL"),  # project coordination
        (21, 36, "SKILL"),  # time management
        (37, 49, "SKILL"),  # multitasking
        (50, 71, "SKILL"),  # organizational skills
        (72, 87, "SKILL"),  # problem-solving
        (88, 100, "SKILL"),  # collaboration
    ]}),
    ("quality assurance software testing test automation bug tracking regression testing user acceptance testing", {"entities": [
        (0, 17, "SKILL"),  # quality assurance
        (18, 34, "SKILL"),  # software testing
        (35, 50, "SKILL"),  # test automation
        (51, 63, "SKILL"),  # bug tracking
        (64, 82, "SKILL"),  # regression testing
        (83, 105, "SKILL"),  # user acceptance testing
    ]}),
    ("business analysis requirement gathering data modeling process mapping stakeholder interviews gap analysis", {"entities": [
        (0, 17, "SKILL"),  # business analysis
        (18, 39, "SKILL"),  # requirement gathering
        (40, 53, "SKILL"),  # data modeling
        (54, 69, "SKILL"),  # process mapping
        (70, 92, "SKILL"),  # stakeholder interviews
        (93, 104, "SKILL"),  # gap analysis
    ]}),
    ("salesforce administration crm customization workflow automation data migration report generation", {"entities": [
        (0, 25, "SKILL"),  # salesforce administration
        (26, 43, "SKILL"),  # crm customization
        (44, 63, "SKILL"),  # workflow automation
        (64, 78, "SKILL"),  # data migration
        (79, 95, "SKILL"),  # report generation
    ]}),
    ("leadership team management strategic planning decision-making delegation conflict management", {"entities": [
        (0, 10, "SKILL"),  # Leadership
        (11, 26, "SKILL"),  # Team management
        (27, 45, "SKILL"),  # strategic planning
        (46, 61, "SKILL"),  # Decision-making
        (62, 72, "SKILL"),  # delegation
        (73, 91, "SKILL"),  # conflict management
    ]}),
    ("public speaking presentation skills audience engagement storytelling persuasion", {"entities": [
        (0, 15, "SKILL"),  # public speaking
        (16, 35, "SKILL"),  # presentation skills
        (36, 55, "SKILL"),  # audience engagement
        (56, 68, "SKILL"),  # storytelling
        (69, 78, "SKILL"),  # persuasion
    ]}),
    ("financial planning investment management retirement planning wealth management risk assessment", {"entities": [
        (0, 18, "SKILL"),  # financial planning
        (19, 40, "SKILL"),  # investment management
        (41, 60, "SKILL"),  # retirement planning
        (61, 78, "SKILL"),  # wealth management
        (79, 93, "SKILL"),  # risk assessment
    ]}),
    ("agile methodology sprint planning scrum ceremonies backlog grooming agile coaching", {"entities": [
        (0, 17, "SKILL"),  # agile methodology
        (18, 33, "SKILL"),  # sprint planning
        (34, 50, "SKILL"),  # scrum ceremonies
        (51, 67, "SKILL"),  # backlog grooming
        (68, 81, "SKILL"),  # agile coaching
    ]}),
    ("ui/ux design wireframing prototyping user research usability testing user interface design user experience optimization", {"entities": [
        (0, 12, "SKILL"),  # UI/UX design
        (13, 24, "SKILL"),  # wireframing
        (25, 36, "SKILL"),  # prototyping
        (37, 50, "SKILL"),  # user research
        (51, 68, "SKILL"),  # usability testing
        (69, 90, "SKILL"),  # user interface design
        (91, 118, "SKILL"),  # user experience optimization
    ]}),
    ("data entry data processing attention to detail time management organization skills", {"entities": [
        (0, 10, "SKILL"),    # data entry
        (11, 26, "SKILL"),  # data processing
        (27, 46, "SKILL"),  # attention to detail
        (47, 62, "SKILL"),  # time management
        (63, 81, "SKILL"),  # organization skills
    ]}),
    ("network administration system configuration troubleshooting it security network monitoring", {"entities": [
        (0, 22, "SKILL"),  # network administration
        (23, 43, "SKILL"),  # system configuration
        (44, 59, "SKILL"),  # troubleshooting
        (60, 71, "SKILL"),  # it security
        (72, 89, "SKILL"),  # network monitoring
    ]}),
    ("graphic design typography layout design color theory image editing digital illustration", {"entities": [
        (0, 14, "SKILL"),   # graphic design
        (15, 25, "SKILL"),  # typography
        (26, 39, "SKILL"),  # layout design
        (40, 52, "SKILL"),  # color theory
        (53, 66, "SKILL"),  # image editing
        (67, 86, "SKILL"),  # digital illustration
    ]}),
    ("project management risk assessment resource allocation stakeholder communication progress tracking", {"entities": [
        (0, 18, "SKILL"),   # project management
        (19, 34, "SKILL"),  # risk assessment
        (35, 54, "SKILL"),  # resource allocation
        (55, 80, "SKILL"),  # stakeholder communication
        (81, 97, "SKILL"),  # progress tracking
    ]}),
    ("content writing copywriting seo optimization content editing proofreading content marketing", {"entities": [
        (0, 15, "SKILL"),   # content writing
        (16, 27, "SKILL"),  # copywriting
        (28, 44, "SKILL"),  # SEO optimization
        (45, 60, "SKILL"),  # content editing
        (61, 73, "SKILL"),  # proofreading
        (74, 90, "SKILL"),  # content marketing
    ]}),
    ("mechanical engineering CAD modeling stress analysis material science thermodynamics fluid mechanics", {"entities": [
        (0, 21, "SKILL"),   # mechanical engineering
        (23, 35, "SKILL"),  # cad modeling
        (36, 51, "SKILL"),  # stress analysis
        (52, 68, "SKILL"),  # material science
        (69, 83, "SKILL"),  # thermodynamics
        (84, 98, "SKILL"),  # fluid mechanics
    ]}),
    ("customer service problem resolution conflict management empathy patience communication skills", {"entities": [
        (0, 16, "SKILL"),   # customer service
        (17, 35, "SKILL"),  # problem resolution
        (36, 55, "SKILL"),  # conflict management
        (56, 63, "SKILL"),  # empathy
        (64, 72, "SKILL"),  # patience
        (73, 92, "SKILL"),  # communication skills
    ]}),
    ("digital marketing social media management content creation audience engagement analytics reporting", {"entities": [
        (0, 17, "SKILL"),   # digital marketing
        (18, 41, "SKILL"),  # social media management
        (42, 58, "SKILL"),  # content creation
        (59, 78, "SKILL"),  # audience engagement
        (79, 97, "SKILL"),  # analytics reporting
    ]}),
    ("software development coding debugging problem-solving algorithms data structures version control", {"entities": [
        (0, 20, "SKILL"),   # software development
        (21, 27, "SKILL"),  # coding
        (28, 37, "SKILL"),  # debugging
        (38, 53, "SKILL"),  # problem-solving
        (54, 64, "SKILL"),  # algorithms
        (65, 80, "SKILL"),  # data structures
        (81, 95, "SKILL"),  # version control
    ]}),
    ("event planning logistics coordination vendor management budget management negotiation skills", {"entities": [
        (0, 15, "SKILL"),   # event planning
        (15, 37, "SKILL"),  # logistics coordination
        (38, 55, "SKILL"),  # vendor management
        (56, 73, "SKILL"),  # budget management
        (74, 91, "SKILL"),  # negotiation skills
    ]}),
    ("public speaking presentation delivery audience engagement storytelling persuasion", {"entities": [
        (0, 15, "SKILL"),   # public speaking
        (16, 37, "SKILL"),  # presentation delivery
        (38, 57, "SKILL"),  # Audience engagement
        (58, 70, "SKILL"),  # storytelling
        (71, 80, "SKILL"),  # persuasion
    ]}),
    ("data analysis statistical modeling data visualization machine learning algorithms predictive analytics", {"entities": [
        (0, 13, "SKILL"),   # data analysis
        (14, 34, "SKILL"),  # statistical modeling
        (35, 53, "SKILL"),  # data visualization
        (54, 81, "SKILL"),  # machine learning algorithms
        (82, 101, "SKILL"),  # predictive analytics
    ]}),
    ("project management team leadership agile methodologies stakeholder communication risk mitigation", {"entities": [
        (0, 18, "SKILL"),   #project management
        (19, 34, "SKILL"),  # team leadership
        (35, 54, "SKILL"),  # agile methodologies
        (55, 80, "SKILL"),  # stakeholder communication
        (81, 95, "SKILL"),  # risk mitigation
    ]}),
    ("financial planning investment management portfolio analysis retirement planning wealth management", {"entities": [
        (0, 18, "SKILL"),   # financial planning
        (19, 40, "SKILL"),  # investment management
        (41, 59, "SKILL"),  # portfolio analysis
        (60, 79, "SKILL"),  # retirement planning
        (80, 96, "SKILL"),  # wealth management
    ]}),
    ("customer relationship management crm software sales pipeline management lead generation customer retention strategies", {"entities": [
        (0, 32, "SKILL"),   # customer relationship management
        (33, 45, "SKILL"),  # crm software
        (46, 71, "SKILL"),  # sales pipeline management
        (72, 87, "SKILL"),  # lead generation
        (88, 116, "SKILL"), # customer retention strategies
    ]}),
    ("legal research writing legal documents case preparation court representation negotiation advocacy", {"entities": [
        (0, 14, "SKILL"),   # legal research
        (15, 38, "SKILL"),  # writing legal documents
        (39, 55, "SKILL"),  # case preparation
        (56, 76, "SKILL"),  # court representation
        (77, 88, "SKILL"),  # negotiation
        (89, 96, "SKILL"),  # advocacy
    ]}),
    ("database administration sql queries database optimization backup and recovery data integrity security measures", {"entities": [
        (0, 23, "SKILL"),   # database administration
        (24, 35, "SKILL"),  # SQL queries
        (36, 57, "SKILL"),  # database optimization
        (58, 77, "SKILL"),  # backup and recovery
        (78, 92, "SKILL"),  # data integrity
        (93, 109, "SKILL"), # security measures
    ]}),
    ("network administration system configuration network troubleshooting cybersecurity protocols firewall management", {"entities": [
        (0, 22, "SKILL"),   # network administration
        (23, 43, "SKILL"),  # system configuration
        (44, 67, "SKILL"),  # network troubleshooting
        (69, 91, "SKILL"),  # cybersecurity protocols
        (92, 110, "SKILL"), # firewall management
    ]}),
    ("graphic design Adobe Creative Suite typography color theory layout design branding", {"entities": [
        (0, 14, "SKILL"),   # graphic design
        (15, 35, "SKILL"),  # adobe creative suite
        (36, 46, "SKILL"),  # typography
        (47, 59, "SKILL"),  # color theory
        (60, 73, "SKILL"),  # layout design
        (74, 81, "SKILL"),  # branding
    ]}),
    ("event planning budget management vendor negotiation venue selection event promotion logistics coordination", {"entities": [
        (0, 14, "SKILL"),   # event planning
        (15, 32, "SKILL"),  # budget management
        (33, 51, "SKILL"),  # vendor negotiation
        (52, 68, "SKILL"),  # venue selection
        (69, 83, "SKILL"),  # event promotion
        (84, 105, "SKILL"), # logistics coordination
    ]}),
    ("content creation content strategy social media management seo optimization content distribution analytics", {"entities": [
        (0, 16, "SKILL"),   # content creation
        (17, 33, "SKILL"),  # content strategy
        (34, 55, "SKILL"),  # social media management
        (56, 72, "SKILL"),  # seo optimization
        (73, 92, "SKILL"),  # Content distribution
        (93, 103, "SKILL"), # Analytics
    ]}),
    ("quality assurance software testing bug tracking test case development automated testing regression testing", {"entities": [
        (0, 17, "SKILL"),   # quality assurance
        (18, 33, "SKILL"),  # software testing
        (34, 47, "SKILL"),  # bug tracking
        (48, 69, "SKILL"),  # test case development
        (70, 87, "SKILL"),  # automated testing
        (88, 105, "SKILL"), # regression testing
    ]}),
    ("project management stakeholder communication risk assessment project scheduling budget allocation team leadership", {"entities": [
        (0, 18, "SKILL"),   # project management
        (19, 44, "SKILL"),  # stakeholder communication
        (45, 60, "SKILL"),  # risk assessment
        (61, 79, "SKILL"),  # project scheduling
        (80, 97, "SKILL"),  # budget allocation
        (98, 112, "SKILL"), # team leadership
    ]}),
    ("customer service complaint resolution client retention customer satisfaction product knowledge empathy", {"entities": [
        (0, 16, "SKILL"),   # customer service
        (17, 37, "SKILL"),  # complaint resolution
        (38, 54, "SKILL"),  # client retention
        (55, 76, "SKILL"),  # customer satisfaction
        (77, 94, "SKILL"),  # product knowledge
        (95, 101, "SKILL"),  # empathy
    ]}),
    ("web development HTML CSS JavaScript responsive design web accessibility cross-browser compatibility", {"entities": [
        (0, 15, "SKILL"),   # web development
        (16, 20, "SKILL"),  # html
        (21, 24, "SKILL"),  # CSS
        (25, 35, "SKILL"),  # javaScript
        (36, 53, "SKILL"),  # responsive design
        (54, 71, "SKILL"),  # web accessibility
        (72, 98, "SKILL"),  # cross-browser compatibility
    ]}),
    ("legal research writing legal briefs contract negotiation litigation support legal analysis", {"entities": [
        (0, 22, "SKILL"),   # legal research
        (23, 35, "SKILL"),  # legal briefs
        (36, 56, "SKILL"),  # contract negotiation
        (57, 75, "SKILL"),  # litigation support
        (76, 89, "SKILL"),  # legal analysis
    ]}),
    ("data entry data cleaning data analysis data visualization database management spreadsheet proficiency", {"entities": [
        (0, 10, "SKILL"),     # Data entry
        (11, 24, "SKILL"),   # data cleaning
        (25, 38, "SKILL"),   # data analysis
        (39, 57, "SKILL"),   # data visualization
        (58, 77, "SKILL"),   # database management
        (78, 100, "SKILL"),   # spreadsheet proficiency
    ]}),
    ("public speaking presentation design audience engagement storytelling persuasion", {"entities": [
        (0, 15, "SKILL"),   # public speaking
        (16, 35, "SKILL"),  # presentation design
        (35, 54, "SKILL"),  # audience engagement
        (55, 67, "SKILL"),  # storytelling
        (69, 78, "SKILL"),  # persuasion
    ]}),
    ("network administration cybersecurity threat detection incident response firewall configuration VPN management", {"entities": [
        (0, 22, "SKILL"),   # Network administration
        (23, 36, "SKILL"),  # cybersecurity
        (37, 53, "SKILL"),  # Threat detection
        (54, 71, "SKILL"),  # Incident response
        (72, 94, "SKILL"),  # Firewall configuration
        (95, 108, "SKILL"), # VPN management
    ]}),
    ("graphic design Adobe Photoshop Illustrator InDesign typography color theory layout design", {"entities": [
        (0, 14, "SKILL"),   # graphic design
        (15, 30, "SKILL"),  # adobe Photosho
        (43, 60, "SKILL"),  # Typography
        (61, 73, "SKILL"),  # Color theory
        (74, 86, "SKILL"),  # Layout design
    ]}),
    ("human resources recruitment employee onboarding performance appraisal HR policies conflict resolution", {"entities": [
        (0, 15, "SKILL"),   # human resources
        (16, 27, "SKILL"),  # recruitment
        (28, 47, "SKILL"),  # employee onboarding
        (48, 69, "SKILL"),  # performance appraisal
        (70, 81, "SKILL"),  # hr policies
        (82, 100, "SKILL"), # conflict resolution
    ]}),
    ("event planning venue selection vendor coordination budget management logistics execution event marketing", {"entities": [
        (0, 14, "SKILL"),   # event planning
        (15, 30, "SKILL"),  # venue selection
        (31, 50, "SKILL"),  # vendor coordination
        (51, 68, "SKILL"),  # budget management
        (69, 88, "SKILL"),  # logistics execution
        (89, 103, "SKILL"),  # event marketing
    ]}),
    ("medical coding billing insurance claims processing healthcare terminology HIPAA compliance patient confidentiality", {"entities": [
        (0, 14, "SKILL"),   # Medical coding
        (15, 22, "SKILL"),  # billing
        (23, 50, "SKILL"),  # insurance claims processing
        (51, 73, "SKILL"),  # healthcare terminology
        (74, 90, "SKILL"),  # HIPAA compliance
        (91, 113, "SKILL"), # patient confidentiality
    ]}),
    ("data analysis statistical modeling data visualization machine learning algorithms predictive analytics", {"entities": [
    (0, 13, "SKILL"),  # data analysis
    (14, 34, "SKILL"),  # statistical modeling
    (35, 53, "SKILL"),  # data visualization
    (54, 81, "SKILL"),  # machine learning algorithms
    (82, 101, "SKILL"),  # predictive analytics
    ]}),
    ("project management team leadership agile methodologies stakeholder communication risk mitigation", {"entities": [
    (0, 18, "SKILL"),  # project management
    (19, 34, "SKILL"),  # team leadership
    (35, 54, "SKILL"),  # agile methodologies
    (55, 80, "SKILL"),  # stakeholder communication
    (81, 95, "SKILL"),  # risk mitigation
    ]}),
    ("financial planning investment management portfolio analysis retirement planning wealth management", {"entities": [
    (0, 18, "SKILL"),  # financial planning
    (19, 40, "SKILL"),  # investment management
    (41, 59, "SKILL"),  # portfolio analysis
    (60, 79, "SKILL"),  # retirement planning
    (80, 96, "SKILL"),  # wealth management
    ]}),
    ("customer relationship management crm software sales pipeline management lead generation customer retention strategies", {"entities": [
    (0, 32, "SKILL"),  # customer relationship management
    (33, 45, "SKILL"),  # CRM software
    (46, 71, "SKILL"),  # sales pipeline management
    (72, 87, "SKILL"),  # lead generation
    (88, 116, "SKILL"),  # customer retention strategies
    ]}),
    ("software engineering software development coding debugging problem-solving", {"entities": [
    (0, 20, "SKILL"),  # software engineering
    (21, 41, "SKILL"),  # software development
    (42, 48, "SKILL"),  # coding
    (49, 58, "SKILL"),  # debugging
    (59, 73, "SKILL"),  # problem-solving
    ]}),
    ("data analysis data visualization statistical modeling machine learning predictive analytics", {"entities": [
    (0, 13, "SKILL"),  # data analysis
    (14, 32, "SKILL"),  # data visualization
    (33, 52, "SKILL"),  # statistical modeling
    (54, 70, "SKILL"),  # machine learning
    (71, 90, "SKILL"),  # predictive analytics
    ]}),
    ("project management team leadership stakeholder communication risk assessment agile methodology", {"entities": [
    (0, 18, "SKILL"),  # project management
    (19, 34, "SKILL"),  # team leadership
    (35, 60, "SKILL"),  # stakeholder communication
    (61, 76, "SKILL"),  # risk assessment
    (77, 93, "SKILL"),  # agile methodology
    ]}),
    ("customer service communication problem resolution conflict management empathy", {"entities": [
        (0, 16, "SKILL"),  # customer service
        (17, 30, "SKILL"),  # communication
        (31, 49, "SKILL"),  # problem resolution
        (50, 69, "SKILL"),  # conflict management
        (70, 76, "SKILL"), # empathy
    ]}),
    ("web development responsive design front-end frameworks back-end development API integration", {"entities": [
    (0, 15, "SKILL"),  # web development
    (16, 33, "SKILL"),  # responsive design
    (34, 54, "SKILL"),  # front-end frameworks
    (55, 74, "SKILL"),  # back-end development
    (76, 90, "SKILL"),  # API integration
    ]}),
    ("sales negotiation client acquisition market research lead generation CRM management", {"entities": [
    (0, 17, "SKILL"),    # sales
    (18, 36, "SKILL"),  # client acquisition
    (37, 52, "SKILL"),  # market research
    (53, 67, "SKILL"),  # lead generation
    (69, 81, "SKILL"),  # crm management
    ]}),
]

transformed_training_data = [
    (text.lower(), annotation) 
    for text, annotation in training_data
]

examples = []
for text, annotations in training_data:
    doc = nlp.make_doc(text)
    example = Example.from_dict(doc, annotations)
    examples.append(example)

# Train the model
nlp.begin_training()
for _ in range(25):  
    for example in examples:
        nlp.update([example], drop=0.5)  # Adjust dropout rate as needed


# Save the trained model
nlp.to_disk("custom_ner_model")


nlp = spacy.load("custom_ner_model")


text = "i'm good at research lead generation CRM management"
text_lowercase = text.lower()

# Process the text
doc = nlp(text_lowercase)

# Access named entities
skills = [ent.text for ent 
          in doc.ents if ent.label_ == "SKILL"]

# Print identified skills
print("Identified Skills:")
for skill in skills:
    print("-", skill)
# Out:
# /home/dell/.local/lib/python3.8/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "family medicine health assessment pediatric care c..." with entities "[(0, 15, 'SKILL'), (16, 33, 'SKILL'), (34, 48, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/dell/.local/lib/python3.8/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "account management client relations marketing stra..." with entities "[(0, 18, 'SKILL'), (19, 35, 'SKILL'), (36, 56, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ...

# %%
import spacy
from spacy.training.example import Example

# trained model
nlp = spacy.load("custom_ner_model")

test_data = [
     ("software development coding debugging problem-solving algorithms data structures version control", {"entities": [
        (0, 20, "SKILL"),   # software development
        (21, 27, "SKILL"),  # coding
        (28, 37, "SKILL"),  # debugging
        (38, 53, "SKILL"),  # problem-solving
        (54, 64, "SKILL"),  # algorithms
        (65, 80, "SKILL"),  # data structures
        (81, 95, "SKILL"),  # version control
    ]}),
    ("event planning logistics coordination vendor management budget management negotiation skills", {"entities": [
        (0, 15, "SKILL"),   # event planning
        (15, 37, "SKILL"),  # logistics coordination
        (38, 55, "SKILL"),  # vendor management
        (56, 73, "SKILL"),  # budget management
        (74, 91, "SKILL"),  # negotiation skills
    ]}),
    ("public speaking presentation delivery audience engagement storytelling persuasion", {"entities": [
        (0, 15, "SKILL"),   # public speaking
        (16, 37, "SKILL"),  # presentation delivery
        (38, 57, "SKILL"),  # Audience engagement
        (58, 70, "SKILL"),  # storytelling
        (71, 80, "SKILL"),  # persuasion
    ]}),
    ("data analysis statistical modeling data visualization machine learning algorithms predictive analytics", {"entities": [
        (0, 13, "SKILL"),   # data analysis
        (14, 34, "SKILL"),  # statistical modeling
        (35, 53, "SKILL"),  # data visualization
        (54, 81, "SKILL"),  # machine learning algorithms
        (82, 101, "SKILL"),  # predictive analytics
    ]}),
    ("project management team leadership agile methodologies stakeholder communication risk mitigation", {"entities": [
        (0, 18, "SKILL"),   #project management
        (19, 34, "SKILL"),  # team leadership
        (35, 54, "SKILL"),  # agile methodologies
        (55, 80, "SKILL"),  # stakeholder communication
        (81, 95, "SKILL"),  # risk mitigation
    ]}),
    ("financial planning investment management portfolio analysis retirement planning wealth management", {"entities": [
        (0, 18, "SKILL"),   # financial planning
        (19, 40, "SKILL"),  # investment management
        (41, 59, "SKILL"),  # portfolio analysis
        (60, 79, "SKILL"),  # retirement planning
        (80, 96, "SKILL"),  # wealth management
    ]}),
    ("customer relationship management crm software sales pipeline management lead generation customer retention strategies", {"entities": [
        (0, 32, "SKILL"),   # customer relationship management
        (33, 45, "SKILL"),  # crm software
        (46, 71, "SKILL"),  # sales pipeline management
        (72, 87, "SKILL"),  # lead generation
        (88, 116, "SKILL"), # customer retention strategies
    ]}),
    ("legal research writing legal documents case preparation court representation negotiation advocacy", {"entities": [
        (0, 14, "SKILL"),   # legal research
        (15, 38, "SKILL"),  # writing legal documents
        (39, 55, "SKILL"),  # case preparation
        (56, 76, "SKILL"),  # court representation
        (77, 88, "SKILL"),  # negotiation
        (89, 96, "SKILL"),  # advocacy
    ]}),
    ("database administration sql queries database optimization backup and recovery data integrity security measures", {"entities": [
        (0, 23, "SKILL"),   # database administration
        (24, 35, "SKILL"),  # SQL queries
        (36, 57, "SKILL"),  # database optimization
        (58, 77, "SKILL"),  # backup and recovery
        (78, 92, "SKILL"),  # data integrity
        (93, 109, "SKILL"), # security measures
    ]}),
    ("network administration system configuration network troubleshooting cybersecurity protocols firewall management", {"entities": [
        (0, 22, "SKILL"),   # network administration
        (23, 43, "SKILL"),  # system configuration
        (44, 67, "SKILL"),  # network troubleshooting
        (69, 91, "SKILL"),  # cybersecurity protocols
        (92, 110, "SKILL"), # firewall management
    ]}),
    ("graphic design Adobe Creative Suite typography color theory layout design branding", {"entities": [
        (0, 14, "SKILL"),   # graphic design
        (15, 35, "SKILL"),  # adobe creative suite
        (36, 46, "SKILL"),  # typography
        (47, 59, "SKILL"),  # color theory
        (60, 73, "SKILL"),  # layout design
        (74, 81, "SKILL"),  # branding
    ]}),
    ("event planning budget management vendor negotiation venue selection event promotion logistics coordination", {"entities": [
        (0, 14, "SKILL"),   # event planning
        (15, 32, "SKILL"),  # budget management
        (33, 51, "SKILL"),  # vendor negotiation
        (52, 68, "SKILL"),  # venue selection
        (69, 83, "SKILL"),  # event promotion
        (84, 105, "SKILL"), # logistics coordination
    ]}),
    ("content creation content strategy social media management seo optimization content distribution analytics", {"entities": [
        (0, 16, "SKILL"),   # content creation
        (17, 33, "SKILL"),  # content strategy
        (34, 55, "SKILL"),  # social media management
        (56, 72, "SKILL"),  # seo optimization
        (73, 92, "SKILL"),  # Content distribution
        (93, 103, "SKILL"), # Analytics
    ]}),
    ("quality assurance software testing bug tracking test case development automated testing regression testing", {"entities": [
        (0, 17, "SKILL"),   # quality assurance
        (18, 33, "SKILL"),  # software testing
        (34, 47, "SKILL"),  # bug tracking
        (48, 69, "SKILL"),  # test case development
        (70, 87, "SKILL"),  # automated testing
        (88, 105, "SKILL"), # regression testing
    ]}),
    ("project management stakeholder communication risk assessment project scheduling budget allocation team leadership", {"entities": [
        (0, 18, "SKILL"),   # project management
        (19, 44, "SKILL"),  # stakeholder communication
        (45, 60, "SKILL"),  # risk assessment
        (61, 79, "SKILL"),  # project scheduling
        (80, 97, "SKILL"),  # budget allocation
        (98, 112, "SKILL"), # team leadership
    ]}),
    ("i'm good at research and lead generation", {"entities": [(11, 19, "SKILL"), (24, 38, "SKILL")]}),
    ("CRM management is one of my skills", {"entities": [(0, 14, "SKILL")]}),
     ("social media platforms eg facebook twitter instagram content creation scheduling social media analytics insights community engagement paid social advertising",
     {"entities": [
        (53, 84, "SKILL"),  # content creation and scheduling
        (85, 120, "SKILL"),  # social media analytics and insights
        (121, 141, "SKILL"),  # community engagement
        (142, 164, "SKILL")  # paid social advertising
    ]}),
    ("html css javascript frontend frameworks eg react angular user experience ux",
     {"entities": [
        (0, 4, "SKILL"),  # html
        (5, 8, "SKILL"),  # css
        (9, 19, "SKILL"),  # javascript
        (20, 38, "SKILL"),  # frontend frameworks
        (57, 74, "SKILL")  # user experience ux
    ]}),
    ("i am proficient in python and java", {"entities": [
        (19, 25, "SKILL"),
        (30, 33, "SKILL")
    ]}),
    ("quality control processes and methodologies statistical process control (spc) root cause analysis and corrective action quality management systems (e.g., iso 9001) compliance and regulatory knowledge", {"entities": [
        (0, 43, "SKILL"),  # quality control processes and methodologies
        (44, 77, "SKILL"),  # Statistical process control (SPC)
        (78, 119, "SKILL"),  # root cause analysis and corrective action
        (120, 146, "SKILL"),  # quality management systems (e.g., ISO 9001)
        (164, 198, "SKILL")  # compliance and regulatory knowledge
    ]}),
    ("wireless network design and architecture wi-fi standards and protocols rf (radio frequency) planning and optimization wireless security protocols troubleshooting wireless network issues", {"entities": [
        (0, 40, "SKILL"),  # wireless network design and architecture
        (41, 70, "SKILL"),  # wi-fi standards and protocols
        (71, 117, "SKILL"),  # RF (Radio Frequency) planning and optimization
        (118, 145, "SKILL"),  # wireless security protocols
        (146, 184, "SKILL")  # troubleshooting wireless network issues
    ]}),
    ("event planning conference logistics budget management vendor coordination marketing and promotion client relations", {"entities": [
        (0, 14, "SKILL"),  # event planning
        (15, 35, "SKILL"),  # conference logistics
        (36, 53, "SKILL"),  # budget management
        (54, 73, "SKILL"),  # vendor coordination
        (74, 97, "SKILL"),  # marketing and promotion
        (98, 113, "SKILL"),  # client relations
    ]}),
    ("quality assurance processes testing methodologies bug tracking and reporting test case development regression testing", {"entities": [
        (0, 26, "SKILL"),  # quality assurance processes
        (27, 49, "SKILL"),  # testing methodologies
        (50, 76, "SKILL"),  # bug tracking and reporting
        (77, 98, "SKILL"),  # test case development
        (99, 116, "SKILL"),  # regression testing
    ]}),
    ("teaching pedagogy classroom management curriculum development student assessment differentiated instruction", {"entities": [
        (0, 17, "SKILL"),  # teaching pedagogy
        (18, 38, "SKILL"),  # classroom management
        (39, 61, "SKILL"),  # curriculum development
        (62, 80, "SKILL"),  # student assessment
        (81, 106, "SKILL"),  # differentiated instruction
    ]}),
    ("ui design principles and best practices graphic design tools typography and color theory visual design and layout responsive design", {"entities": [
        (0, 9, "SKILL"),  # ui design principles and best practices
        (40, 60, "SKILL"),  # graphic design tools
        (61, 88, "SKILL"),  # typography and color theory
        (89, 113, "SKILL"),  # visual design and layout
        (114, 130, "SKILL"),  # responsive design
    ]}),
    ("interaction design principles user behavior and psychology wireframing and prototyping tools animation and micro-interaction design collaborative design processes", {"entities": [
        (0, 29, "SKILL"),  # interaction design principles
        (30, 58, "SKILL"),  # user behavior and psychology
        (59, 92, "SKILL"),  # wireframing and prototyping tools
        (93, 131, "SKILL"),  # animation and micro-interaction design
        (131, 161, "SKILL"),  # collaborative design processes
    ]}),
    ("wedding planning vendor coordination event management", {"entities": [
        (0, 16, "SKILL"),  # wedding planning
        (17, 36, "SKILL"),  # vendor coordination
        (37, 52, "SKILL"),  # event management
    ]}),
    ("performance testing load testing stress testing test scenarios performance monitoring benchmarking performance analysis", {"entities": [
        (0, 19, "SKILL"),  # performance testing
        (20, 32, "SKILL"),  # load testing
        (33, 47, "SKILL"),  # stress testing
        (48, 62, "SKILL"),  # test scenarios
        (63, 85, "SKILL"),  # performance monitoring
        (86, 98, "SKILL"),  # benchmarking
        (99, 118, "SKILL"),  # performance analysis
    ]}),
    ("family law divorce proceedings child custody mediation legal counseling court representation", {"entities": [
        (0, 10, "SKILL"),  # family law
        (11, 30, "SKILL"),  # divorce proceedings
        (31, 44, "SKILL"),  # child custody
        (45, 54, "SKILL"),  # mediation
        (55, 71, "SKILL"),  # legal counseling
        (72, 91, "SKILL"),  # court representation
    ]}),
    ("mechanical engineering cad software finite element analysis product development prototyping", {"entities": [
        (0, 22, "SKILL"),  # mechanical engineering
        (23, 35, "SKILL"),  # cad software
        (36, 59, "SKILL"),  # finite element analysis
        (60, 79, "SKILL"),  # product development
        (80, 90, "SKILL"),  # prototyping
    ]}),
    ("network security protocols intrusion detection and prevention security incident response firewall administration vulnerability assessment security policies and procedures log analysis ethical hacking problem-solving communication skills attention to detail", {"entities": [
        (0, 26, "SKILL"),  # network security protocols
        (27, 61, "SKILL"),  # intrusion detection and prevention
        (62, 88, "SKILL"),  # security incident response
        (89, 112, "SKILL"),  # firewall administration
        (113, 137, "SKILL"),  # vulnerability assessment
        (138, 170, "SKILL"),  # security policies and procedures
        (171, 183, "SKILL"),  # log analysis
        (184, 199, "SKILL"),  # ethical hacking
        (200, 215, "SKILL"),  # problem-solving
        (216, 236, "SKILL"),  # communication skills
        (237, 255, "SKILL"),  # attention to detail
    ]}),
    ("account management sales strategy negotiation and closing skills", {"entities": [
        (0, 18, "SKILL"),  # account management
        (19, 33, "SKILL"),  # sales strategy
        (34, 63, "SKILL"),  # negotiation and closing skills
    ]}),
    ("product branding and marketing product lifecycle management cross-functional team collaboration product launch planning market segmentation and targeting", {"entities": [
        (0, 30, "SKILL"),  # product branding and marketing
        (31, 59, "SKILL"),  # product lifecycle management
        (60, 95, "SKILL"),  # cross-functional team collaboration
        (96, 119, "SKILL"),  # product launch planning
        (120, 152, "SKILL"),  # market segmentation and targeting
    ]}),
    ("email deliverability best practices spam filter testing list hygiene blacklist monitoring email authentication deliverability metrics analysis troubleshooting deliverability issues communication skills data analysis attention to detail", {"entities": [
        (0, 12, "SKILL"),  # email deliverability best practices
        (36, 55, "SKILL"),  # spam filter testing
        (56, 68, "SKILL"),  # Lemail deliverability bes
        (69, 89, "SKILL"),  # blacklist monitoring
        (90, 110, "SKILL"),  # email authentication
        (111, 142, "SKILL"),  # deliverability metrics analysis
        (143, 180, "SKILL"),  # troubleshooting deliverability issues
        (181, 201, "SKILL"),  # Communication skills
        (202, 215, "SKILL"),  # data analysis
        (216, 234, "SKILL"),  # attention to detail
    ]}),
    ("human resources recruitment employee onboarding hris record keeping communication skills", {"entities": [
        (0, 15, "SKILL"),  # human resources
        (16, 27, "SKILL"),  # recruitment
        (28, 47, "SKILL"),  # employee onboarding
        (48, 52, "SKILL"),  # hris (hr information systems)
        (53, 67, "SKILL"),  # record keeping
        (68, 87, "SKILL"),  # communication skills
    ]}),
    ("legal administrative tasks document management calendar and docketing transcription file organization communication with clients and courts knowledge of legal terminology attention to detail multitasking computer skills", {"entities": [
        (0, 26, "SKILL"),  # legal administrative tasks
        (27, 46, "SKILL"),  # document management
        (47, 65, "SKILL"),  # calendar docketing
        (66, 78, "SKILL"),  # transcription
        (80, 97, "SKILL"),  # file organization
        (98, 131, "SKILL"),  # communication with clients courts
        (132, 162, "SKILL"),  # knowledge of legal terminology
        (163, 182, "SKILL"),  # attention to detail
        (183, 195, "SKILL"),  # multitasking
        (196, 210, "SKILL"),  # computer skills
    ]}),
]

transformed_test_data = [
    (text.lower(), annotation) 
    for text, annotation in test_data
]

test_examples = []
for text, annotations in transformed_test_data:
    doc = nlp.make_doc(text)
    example = Example.from_dict(doc, annotations)
    test_examples.append(example)

# Evaluate the model
scores = nlp.evaluate(test_examples)
print("Accuracy:", scores["ents_p"])
print("Precision:", scores["ents_r"])
print("Recall:", scores["ents_f"])

# Process a sample text
sample_text = "network security protocols intrusion detection and prevention security incident response firewall administration vulnerability assessment security policies and procedures log analysis ethical hacking problem-solving communication skills attention to detail"
doc = nlp(sample_text.lower())

# Print identified skills
print("\nIdentified Skills:")
for ent in doc.ents:
    print("-", ent.text)
# Out:
# Accuracy: 0.9097222222222222
# Precision: 0.9357142857142857
# Recall: 0.9225352112676057
#
# Identified Skills:
# - network security protocols
# - intrusion detection and prevention
# - security incident response
# - firewall administration
# - vulnerability assessment
# - security policies and procedures
# - log analysis
# - ethical hacking
# - problem-solving
# - communication skills
# - attention to detail

# %%
from sklearn.model_selection import train_test_split

# Splitting the DataFrame into training and testing data
train_data, test_data = train_test_split(working, test_size=0.5, random_state=42)
display(train_data)
# Out:
#                   Job Id     Experience Qualifications Salary Range  \
# 80117   2235359519051687   4 to 8 years       ['bcom']      64-118k
# 4035    1217292265285214  3 to 10 years        ['bba']      61-111k
# 30574    767518180861629   5 to 8 years        ['bba']      64-128k
# 97849   3061280218965390  1 to 10 years      ['mtech']      62-122k
# 4706    1725766660276910  5 to 15 years        ['phd']       65-87k
# ...                  ...            ...            ...          ...
# 54886   1123645535815600  5 to 12 years         ['ba']      59-130k
# 76820    993016756786805   0 to 8 years        ['mba']       55-99k
# 103694  1708080200715070  5 to 15 years      ['btech']       65-80k
# 860      894449319093419  2 to 10 years        ['phd']      65-102k
# 15795    998887654849277  4 to 10 years       ['mcom']       64-96k
#
#                        location     Country      Work Type  Company Size  \
# 80117                      apia       samoa     ['intern']         57895
# ...

# %%
# toknizing the skills using the custom spacy

nlp = spacy.load("custom_ner_model")

dataset = working.to_dict(orient="records")

text_column = "skills"

for row in dataset:
   
    text = row[text_column]
    
    doc = nlp(text.lower())  
    
    # Extract identified skills
    identified_skills = [ent.text for ent in doc.ents if 
    ent.label_ == "SKILL"]
    
    
    row["tokenized_skills"] = identified_skills

# Convert the dataset back to a DataFrame
working = pd.DataFrame(dataset)


display(working)
# Out:
#                   Job Id     Experience Qualifications Salary Range  \
# 0       1089843540111562  5 to 15 years      ['mtech']       59-99k
# 1        398454096642776  2 to 12 years        ['bca']      56-116k
# 2        481640072963533  0 to 12 years        ['phd']      61-104k
# 3        688192671473044  4 to 11 years        ['phd']       65-91k
# 4        117057806156508  1 to 12 years        ['mba']       64-87k
# ...                  ...            ...            ...          ...
# 107359  1983179143713411  3 to 12 years        ['bba']      60-128k
# 107360   669857235415970  2 to 15 years        ['mba']      59-121k
# 107361  2722200185343244  0 to 11 years        ['mca']       59-80k
# 107362  2740245700222760   1 to 9 years        ['bba']       63-83k
# 107363  2728583024325919  0 to 13 years        ['bca']       59-98k
#
#                 location              Country      Work Type  Company Size  \
# ...

# %%
working.to_csv('working_best.csv', index=False)

# %%
import pandas as pd 
training = pd.read_csv('working_best.csv')
display(training)
# Out:
#                   Job Id     Experience Qualifications Salary Range  \
# 0       1089843540111562  5 to 15 years      ['mtech']       59-99k
# 1        398454096642776  2 to 12 years        ['bca']      56-116k
# 2        481640072963533  0 to 12 years        ['phd']      61-104k
# 3        688192671473044  4 to 11 years        ['phd']       65-91k
# 4        117057806156508  1 to 12 years        ['mba']       64-87k
# ...                  ...            ...            ...          ...
# 107359  1983179143713411  3 to 12 years        ['bba']      60-128k
# 107360   669857235415970  2 to 15 years        ['mba']      59-121k
# 107361  2722200185343244  0 to 11 years        ['mca']       59-80k
# 107362  2740245700222760   1 to 9 years        ['bba']       63-83k
# 107363  2728583024325919  0 to 13 years        ['bca']       59-98k
#
#                 location              Country      Work Type  Company Size  \
# ...

# %%
working_with = training.drop(['location', 'Country', 'Company Size', 'skills', 'Contact Person', 'Preference',], axis=1)

working_with['Company Profile'] = working_with['Company Profile'].str.replace('^sector\s+', '', regex=True)

display(working_with)
# Out:
#                   Job Id     Experience Qualifications Salary Range  \
# 0       1089843540111562  5 to 15 years      ['mtech']       59-99k
# 1        398454096642776  2 to 12 years        ['bca']      56-116k
# 2        481640072963533  0 to 12 years        ['phd']      61-104k
# 3        688192671473044  4 to 11 years        ['phd']       65-91k
# 4        117057806156508  1 to 12 years        ['mba']       64-87k
# ...                  ...            ...            ...          ...
# 107359  1983179143713411  3 to 12 years        ['bba']      60-128k
# 107360   669857235415970  2 to 15 years        ['mba']      59-121k
# 107361  2722200185343244  0 to 11 years        ['mca']       59-80k
# 107362  2740245700222760   1 to 9 years        ['bba']       63-83k
# 107363  2728583024325919  0 to 13 years        ['bca']       59-98k
#
#             Work Type Job Posting Date                         Job Title  \
# 0          ['intern']       2022-04-24  ['digital marketing specialist']
# ...

# %%
working_with.to_csv('working_with.csv', index=False)

# %%
import pandas as pd 
training = pd.read_csv('working_with.csv')
display(training)
# Out:
#                   Job Id     Experience Qualifications Salary Range  \
# 0       1089843540111562  5 to 15 years      ['mtech']       59-99k
# 1        398454096642776  2 to 12 years        ['bca']      56-116k
# 2        481640072963533  0 to 12 years        ['phd']      61-104k
# 3        688192671473044  4 to 11 years        ['phd']       65-91k
# 4        117057806156508  1 to 12 years        ['mba']       64-87k
# ...                  ...            ...            ...          ...
# 107359  1983179143713411  3 to 12 years        ['bba']      60-128k
# 107360   669857235415970  2 to 15 years        ['mba']      59-121k
# 107361  2722200185343244  0 to 11 years        ['mca']       59-80k
# 107362  2740245700222760   1 to 9 years        ['bba']       63-83k
# 107363  2728583024325919  0 to 13 years        ['bca']       59-98k
#
#             Work Type Job Posting Date                         Job Title  \
# 0          ['intern']       2022-04-24  ['digital marketing specialist']
# ...

# %%
# Assuming your dataset is stored in a list named 'cleaned_dataset'
total_length = len(training)
part_length = total_length // 20

parts = [training[i:i+part_length] for i in range(0, total_length, part_length)]

# Now parts is a list containing 15 equal parts of your dataset
Working_part = parts[0]

display(Working_part)
# Out:
#                 Job Id     Experience Qualifications Salary Range  \
# 0     1089843540111562  5 to 15 years      ['mtech']       59-99k
# 1      398454096642776  2 to 12 years        ['bca']      56-116k
# 2      481640072963533  0 to 12 years        ['phd']      61-104k
# 3      688192671473044  4 to 11 years        ['phd']       65-91k
# 4      117057806156508  1 to 12 years        ['mba']       64-87k
# ...                ...            ...            ...          ...
# 5363  1749823191807562  4 to 13 years        ['mca']      60-125k
# 5364   940884629266821  5 to 11 years       ['mcom']      62-101k
# 5365  2153156116837823  2 to 13 years       ['mcom']      60-124k
# 5366  2536515942496064  0 to 10 years       ['mcom']       55-80k
# 5367  2917881076728802   2 to 9 years        ['bca']      65-115k
#
#           Work Type Job Posting Date                         Job Title  \
# 0        ['intern']       2022-04-24  ['digital marketing specialist']
# ...

# %%
unique_skills = training['tokenized_skills'].unique()
print(unique_skills)
# Out:
# ["['social media platforms eg', 'content creation and scheduling', 'social media', 'analytics and insights', 'community engagement', 'paid', 'social advertising']"
#  "['html', 'css', 'javascript', 'frontend frameworks eg react', 'user experience ux']"
#  "['quality control processes and methodologies', 'statistical process control', 'spc root', 'cause analysis and corrective action', 'quality management systems eg iso 9001', 'compliance and regulatory knowledge']"
#  "['wireless network design and architecture', 'wifi standards and protocols', 'rf radio frequency planning and optimization', 'wireless security protocols', 'troubleshooting', 'wireless network issues']"
#  "['event planning', 'conference logistics', 'budget management', 'vendor coordination', 'marketing and promotion', 'client relations']"
#  "['quality assurance processes testing', 'methodologies', 'eg manual', 'automated bug', 'tracking and reporting', 'test case development', 'regression testing']"
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# Sample skill data
skills = [
    "html", "css", "javascript", "react", "angular", "python", "data analysis", "machine learning",
    "project management", "database", "sql", "nosql", "web development", "front-end", "back-end"
]

# Feature extraction using TF-IDF
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(skills)

# Clustering using KMeans
n_clusters =3
kmeans = KMeans(n_clusters=n_clusters)
kmeans.fit(X)

# Determine the cluster centers
cluster_centers = kmeans.cluster_centers_

# Determine which cluster each skill belongs to
skill_clusters = kmeans.predict(X)

# Determine the demand level of each cluster
cluster_sizes = [sum(skill_clusters == i) for i in range(n_clusters)]
highest_demand_cluster = cluster_sizes.index(max(cluster_sizes))
lowest_demand_cluster = cluster_sizes.index(min(cluster_sizes))
middle_demand_cluster = [i for i in range(n_clusters) if i != highest_demand_cluster and i != lowest_demand_cluster][0]

# Determine the demand level of each skill
demand_levels = []
for skill, cluster in zip(skills, skill_clusters):
    if cluster == highest_demand_cluster:
        demand_levels.append("High demand")
    elif cluster == lowest_demand_cluster:
        demand_levels.append("Low demand")
    else:
        demand_levels.append("Middle demand")

# Now you have the demand level of each skill
for skill, demand_level in zip(skills, demand_levels):
    print(f"Skill: {skill}, Demand Level: {demand_level}")
# Out:
# /home/dell/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Skill: html, Demand Level: High demand
# Skill: css, Demand Level: High demand
# Skill: javascript, Demand Level: High demand
# Skill: react, Demand Level: High demand
# Skill: angular, Demand Level: High demand
# Skill: python, Demand Level: High demand
# Skill: data analysis, Demand Level: High demand
# Skill: machine learning, Demand Level: High demand
# Skill: project management, Demand Level: High demand
# Skill: database, Demand Level: High demand
# Skill: sql, Demand Level: Low demand
# Skill: nosql, Demand Level: High demand
# Skill: web development, Demand Level: High demand
# Skill: front-end, Demand Level: Middle demand
# Skill: back-end, Demand Level: Middle demand

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import pandas as pd

skills_series = training['tokenized_skills']

skills = skills_series.tolist()

# Feature extraction using TF-IDF
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(skills)


n_clusters = 3 
kmeans = KMeans(n_clusters=n_clusters)
kmeans.fit(X)

# Predict the cluster for each skill
skill_clusters = kmeans.predict(X)

# Calculate the distribution of samples across clusters
cluster_counts = np.bincount(skill_clusters)
total_samples = len(skills)

# Find the cluster with the highest and lowest demand
highest_demand_cluster = np.argmax(cluster_counts)
lowest_demand_cluster = np.argmin(cluster_counts)

# Initialize lists to store skills and demand levels
skills_list = []
demand_levels_list = []

# Iterate through each skill and determine its demand level
for skill, cluster in zip(skills, skill_clusters):
    if cluster == highest_demand_cluster:
        demand_level = "High demand"
    elif cluster == lowest_demand_cluster:
        demand_level = "Low demand"
    else:
        demand_level = "Middle demand"
    skills_list.append(skill)
    demand_levels_list.append(demand_level)

# Create the DataFrame
demand_df = pd.DataFrame({'Skill': skills_list, 'Demand Level': demand_levels_list})

# Display the DataFrame containing skills and their demand levels
print(demand_df)
# Out:
# /home/dell/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#                                                     Skill   Demand Level
# 0       ['social media platforms eg', 'content creatio...  Middle demand
# 1       ['html', 'css', 'javascript', 'frontend framew...     Low demand
# 2       ['quality control processes and methodologies'...    High demand
# 3       ['wireless network design and architecture', '...    High demand
# 4       ['event planning', 'conference logistics', 'bu...    High demand
# ...                                                   ...            ...
# 107359  ['research and development processes', 'produc...    High demand
# 107360  ['ui design principles and best practices', 'g...     Low demand
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# Sample skill data
skills = [
    ['social media platforms', 'content creation', 'and scheduling', 'social media', 'community engagement', 'paid social advertising'],
    ['html', 'css', 'javascript', 'frontend frameworks', 'user experience ux'],
    ['quality control processes and methodologies', 'statistical process control', 'spc root', 'cause analysis and corrective', 'quality management systems eg', 'regulatory knowledge'],
    ['wireless network design', 'wifi standards and protocols', 'rf radio frequency', 'and optimization', 'wireless security protocols', 'troubleshooting', 'wireless network issues'],
    ['event planning', 'conference logistics', 'budget management', 'vendor coordination', 'marketing and promotion', 'client relations'],
    ['ui design', 'graphic design', 'adobe photoshop', 'typography and color theory', 'visual design and layout', 'responsive design'],
    ['account management', 'client relations', 'marketing strategies', 'campaign optimization', 'data analysis', 'communication skills'],
    ['product innovation', 'prototype development'],
    ['test automation', 'test framework development']
]

# Flatten the list of skills
flattened_skills = [skill for sublist in skills for skill in sublist]

# Feature extraction using TF-IDF
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(flattened_skills)

# Apply K-means clustering
n_clusters = 3 
kmeans = KMeans(n_clusters=n_clusters)
kmeans.fit(X)

# Predict the cluster for each skill
skill_clusters = kmeans.predict(X)

# Calculate the distribution of samples across clusters
cluster_counts = np.bincount(skill_clusters)
total_samples = len(flattened_skills)

# Find the cluster with the highest and lowest demand
highest_demand_cluster = np.argmax(cluster_counts)
lowest_demand_cluster = np.argmin(cluster_counts)


skills_list = []
demand_levels_list = []

# Iterate through each individual skill and determine its demand level
for skill, cluster in zip(flattened_skills, skill_clusters):
    if cluster == highest_demand_cluster:
        demand_level = "High demand"
    elif cluster == lowest_demand_cluster:
        demand_level = "Low demand"
    else:
        demand_level = "Middle demand"
    skills_list.append(skill)
    demand_levels_list.append(demand_level)

# Create the DataFrame with additional columns
demand_df = pd.DataFrame({'Skill': skills_list, 'Demand Level': demand_levels_list})

# Display the DataFrame containing skills and their demand levels
print(demand_df)
# Out:
#                                           Skill   Demand Level
# 0                        social media platforms     Low demand
# 1                              content creation    High demand
# 2                                and scheduling    High demand
# 3                                  social media     Low demand
# 4                          community engagement    High demand
# 5                       paid social advertising     Low demand
# 6                                          html    High demand
# 7                                           css    High demand
# 8                                    javascript    High demand
# 9                           frontend frameworks    High demand
# 10                           user experience ux    High demand
# 11  quality control processes and methodologies    High demand
# 12                  statistical process control    High demand
# 13                                     spc root    High demand
# ...

# %%
from sklearn.metrics import silhouette_score


silhouette_avg = silhouette_score(X, kmeans.labels_)
print("Silhouette Score:", silhouette_avg)
# Out:
# Silhouette Score: 0.03662463495974151

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer



skills = [
    ['social media platforms', 'content creation', 'and scheduling', 'social media', 'community engagement', 'paid social advertising'],
    ['html', 'css', 'javascript', 'frontend frameworks', 'user experience ux'],
    ['quality control processes and methodologies', 'statistical process control', 'spc root', 'cause analysis and corrective', 'quality management systems eg', 'regulatory knowledge'],
    ['wireless network design', 'wifi standards and protocols', 'rf radio frequency', 'and optimization', 'wireless security protocols', 'troubleshooting', 'wireless network issues'],
    ['event planning', 'conference logistics', 'budget management', 'vendor coordination', 'marketing and promotion', 'client relations'],
    ['ui design', 'graphic design', 'adobe photoshop', 'typography and color theory', 'visual design and layout', 'responsive design'],
    ['account management', 'client relations', 'marketing strategies', 'campaign optimization', 'data analysis', 'communication skills'],
    ['product innovation', 'prototype development'],
    ['test automation', 'test framework development']
]

# Flatten the list of skills
flattened_skills = [skill for sublist in skills for skill in sublist]

# Feature extraction using TF-IDF
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(flattened_skills)

# Apply K-means clustering
n_clusters = 3  # Define the number of clusters
kmeans = KMeans(n_clusters=n_clusters)
kmeans.fit(X)

# Perform PCA to reduce the dimensions to 2
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X.toarray())

# Plot the clusters
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=kmeans.labels_, cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('KMeans Clustering (2D PCA)')
plt.colorbar(label='Cluster')
plt.show()
# Out:
# /home/dell/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans


skills_series = training['tokenized_skills']

# Convert the Series to a list of lists (each sublist represents a skill entry)
skills = [skill.split(', ') for skill in skills_series]

# Flatten the list of skills
flattened_skills = [skill for sublist in skills for skill in sublist]

# Feature extraction using TF-IDF
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(flattened_skills)

# Apply K-means clustering
n_clusters = 3
kmeans = KMeans(n_clusters=n_clusters)
kmeans.fit(X)


skill_clusters = kmeans.predict(X)


cluster_counts = np.bincount(skill_clusters)
total_samples = len(flattened_skills)


highest_demand_cluster = np.argmax(cluster_counts)
lowest_demand_cluster = np.argmin(cluster_counts)


skills_list = []
demand_levels_list = []

# Iterate through each individual skill and determine its demand level
for skill, cluster in zip(flattened_skills, skill_clusters):
    if cluster == highest_demand_cluster:
        demand_level = "High demand"
    elif cluster == lowest_demand_cluster:
        demand_level = "Low demand"
    else:
        demand_level = "Middle demand"
    skills_list.append(skill)
    demand_levels_list.append(demand_level)

# Create the DataFrame with additional columns
demand_df = pd.DataFrame({'Skill': skills_list, 'Demand Level': demand_levels_list})

# Display the DataFrame containing skills and their demand levels
print(demand_df)
# Out:
# /home/dell/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#                                     Skill   Demand Level
# 0            ['social media platforms eg'    High demand
# 1       'content creation and scheduling'  Middle demand
# 2                          'social media'    High demand
# 3                'analytics and insights'  Middle demand
# 4                  'community engagement'    High demand
# ...                                   ...            ...
# 737247           'continuous integration'    High demand
# 737248                        'scripting'    High demand
# 737249              'languages eg python'    High demand
# 737250                   'test reporting'    High demand
# 737251                     'code review']    High demand
#
# ...

# %%
from sklearn.metrics import silhouette_score

# Assuming 'X' is your data and 'kmeans' is your KMeans model
silhouette_avg = silhouette_score(X, kmeans.labels_)
print("Silhouette Score:", silhouette_avg)
# Out:
# Silhouette Score: 0.026219355758354924

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# Sample skill data with demand levels
skills = [
    ['social media platforms', 'content creation', 'and scheduling', 'social media', 'community engagement', 'paid social advertising', 'High'],
    ['html', 'css', 'javascript', 'frontend frameworks', 'user experience ux', 'Middle'],
    ['quality control processes and methodologies', 'statistical process control', 'spc root', 'cause analysis and corrective', 'quality management systems eg', 'regulatory knowledge', 'Low'],
    ['wireless network design', 'wifi standards and protocols', 'rf radio frequency', 'and optimization', 'wireless security protocols', 'troubleshooting', 'wireless network issues', 'High'],
    ['event planning', 'conference logistics', 'budget management', 'vendor coordination', 'marketing and promotion', 'client relations', 'Low'],
    ['ui design', 'graphic design', 'adobe photoshop', 'typography and color theory', 'visual design and layout', 'responsive design', 'Middle'],
    ['account management', 'client relations', 'marketing strategies', 'campaign optimization', 'data analysis', 'communication skills', 'Low'],
    ['product innovation', 'prototype development', 'High'],
    ['test automation', 'test framework development', 'Middle']
]

# Flatten the list of skills
flattened_skills = [skill[:-1] for sublist in skills for skill in sublist]

# Feature extraction using TF-IDF
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(flattened_skills)

# Apply K-means clustering
n_clusters = 3  # Define the number of clusters
kmeans = KMeans(n_clusters=n_clusters)
kmeans.fit(X)

# Predict the cluster for each skill
skill_clusters = kmeans.predict(X)

# Map cluster labels to demand levels
cluster_labels = {
    0: "High demand",
    1: "Low demand",
    2: "Middle demand"
}

# Initialize lists to store skills and demand levels
skills_list = []
demand_levels_list = []

# Map cluster predictions to demand levels
for skill, cluster in zip(flattened_skills, skill_clusters):
    skills_list.append(skill)
    demand_levels_list.append(cluster_labels[cluster])

# Create the DataFrame with additional columns
demand_df = pd.DataFrame({'Skill': skills_list, 'Demand Level': demand_levels_list})

# Display the DataFrame containing skills and their demand levels
print(demand_df)
# Out:
#                                          Skill   Demand Level
# 0                        social media platform    High demand
# 1                              content creatio    High demand
# 2                                and schedulin    High demand
# 3                                  social medi    High demand
# 4                          community engagemen    High demand
# 5                       paid social advertisin    High demand
# 6                                          Hig    High demand
# 7                                          htm    High demand
# 8                                           cs    High demand
# 9                                    javascrip    High demand
# 10                          frontend framework    High demand
# 11                           user experience u    High demand
# 12                                       Middl     Low demand
# 13  quality control processes and methodologie    High demand
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# Assuming 'X' is your TF-IDF matrix and 'kmeans' is your KMeans model

# Perform t-SNE to reduce the dimensions to 2
tsne = TSNE(n_components=3, perplexity=30, n_iter=250)
X_tsne = tsne.fit_transform(X.toarray())

# Plot the clusters
plt.figure(figsize=(8, 6))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=kmeans.labels_, cmap='viridis')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.title('KMeans Clustering (2D t-SNE)')
plt.colorbar(label='Cluster')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer


skills_series = Working_part['tokenized_skills']

# Convert the Series to a list of lists (each sublist represents a skill entry)
skills = [skill.split(', ') for skill in skills_series]

# Flatten the list of skills
flattened_skills = [skill for sublist in skills for skill in sublist]
# Flatten the list of skills
flattened_skills = [skill for sublist in skills for skill in sublist]

# Feature extraction using TF-IDF
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(flattened_skills)

# Apply K-means clustering
n_clusters = 12  # Define the number of clusters
kmeans = KMeans(n_clusters=n_clusters)
kmeans.fit(X)

# Perform PCA to reduce the dimensions to 2
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X.toarray())

# Plot the clusters
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=kmeans.labels_, cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('KMeans Clustering (2D PCA)')
plt.colorbar(label='Cluster')
plt.show()
# Out:
# /home/dell/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer


skills_series = Working_part['tokenized_skills']

# Convert the Series to a list of lists (each sublist represents a skill entry)
flattened_skills = list(set([skill for sublist in skills for skill in sublist]))

# Flatten the list of skills
flattened_skills = [skill for sublist in skills for skill in sublist]


# Feature extraction using TF-IDF
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(flattened_skills)

# Apply K-means clustering
n_clusters = 3  # Define the number of clusters
kmeans = KMeans(n_clusters=n_clusters)
kmeans.fit(X)


# Perform t-SNE to reduce the dimensions to 2
tsne = TSNE(n_components=2, perplexity=30, n_iter=300)
X_tsne = tsne.fit_transform(X.toarray())

# Plot the clusters
plt.figure(figsize=(8, 6))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=kmeans.labels_, cmap='viridis')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.title('KMeans Clustering (2D t-SNE)')
plt.colorbar(label='Cluster')
plt.show()
# Out:
# /home/dell/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer

skills_series = Working_part['tokenized_skills']

# Convert the Series to a list of lists (each sublist represents a skill entry)
flattened_skills = list(set([skill for sublist in skills for skill in sublist]))

# Flatten the list of skills and remove duplicates
flattened_skills = list(set([skill for sublist in skills for skill in sublist]))

# Feature extraction using TF-IDF
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(flattened_skills)

# Apply K-means clustering
n_clusters = 3  # Define the number of clusters
kmeans = KMeans(n_clusters=n_clusters)
kmeans.fit(X)

# Perform t-SNE to reduce the dimensions to 2
tsne = TSNE(n_components=2, perplexity=30, n_iter=300)
X_tsne = tsne.fit_transform(X.toarray())

# Plot the clusters
plt.figure(figsize=(8, 6))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=kmeans.labels_, cmap='viridis')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.title('KMeans Clustering (2D t-SNE)')
plt.colorbar(label='Cluster')
plt.show()
# Out:
# /home/dell/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Assuming 'training' is your DataFrame containing the 'tokenized_skills' column

# Convert the 'tokenized_skills' column to a list of lists
skills = [skill.split(', ') for skill in training['tokenized_skills']]

# Flatten the list of skills
flattened_skills = [skill for sublist in skills for skill in sublist]

# Feature extraction using TF-IDF
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(flattened_skills)

# Apply K-means clustering
n_clusters = 3  # Define the number of clusters
kmeans = KMeans(n_clusters=n_clusters)
kmeans.fit(X)

# Predict the cluster for each skill
skill_clusters = kmeans.predict(X)

# Calculate the silhouette score
silhouette_avg = silhouette_score(X, skill_clusters)
print("Silhouette Score:", silhouette_avg)

# Calculate the distribution of samples across clusters
cluster_counts = np.bincount(skill_clusters)
total_samples = len(flattened_skills)

# Find the cluster with the highest and lowest demand
highest_demand_cluster = np.argmax(cluster_counts)
lowest_demand_cluster = np.argmin(cluster_counts)

# Initialize lists to store skills and demand levels
skills_list = []
demand_levels_list = []

# Iterate through each individual skill and determine its demand level
for skill, cluster in zip(flattened_skills, skill_clusters):
    if cluster == highest_demand_cluster:
        demand_level = "High demand"
    elif cluster == lowest_demand_cluster:
        demand_level = "Low demand"
    else:
        demand_level = "Middle demand"
    skills_list.append(skill)
    demand_levels_list.append(demand_level)

# Create the DataFrame with additional columns
demand_df = pd.DataFrame({'Skill': skills_list, 'Demand Level': demand_levels_list})

# Display the DataFrame containing skills and their demand levels
print(demand_df)
# Out:
# /home/dell/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Silhouette Score: 0.02578339349332492
#                                     Skill   Demand Level
# 0            ['social media platforms eg'  Middle demand
# 1       'content creation and scheduling'    High demand
# 2                          'social media'    High demand
# 3                'analytics and insights'    High demand
# 4                  'community engagement'    High demand
# ...                                   ...            ...
# 737247           'continuous integration'    High demand
# 737248                        'scripting'    High demand
# 737249              'languages eg python'  Middle demand
# 737250                   'test reporting'    High demand
# ...

# %%
# Group the DataFrame by 'Demand Level'
demand_groups = demand_df.groupby('Demand Level')

# Filter the DataFrame for each demand level
low_demand_skills = demand_groups.get_group('Low demand')
middle_demand_skills = demand_groups.get_group('Middle demand')
high_demand_skills = demand_groups.get_group('High demand')

# Print the skills for each demand level
print("Low Demand Skills:")
print(low_demand_skills)

print("\nMiddle Demand Skills:")
print(middle_demand_skills)

print("\nHigh Demand Skills:")
print(high_demand_skills)
# Out:
# Low Demand Skills:
#                           Skill Demand Level
# 85       'communication skills'   Low demand
# 123      'communication skills'   Low demand
# 133      'communication skills'   Low demand
# 142     'communication skills']   Low demand
# 148        'communication with'   Low demand
# ...                         ...          ...
# 737142  'communication skills']   Low demand
# 737151       'communication of'   Low demand
# 737165   'communication skills'   Low demand
# 737186   'communication skills'   Low demand
# 737238  'communication skills']   Low demand
#
# [31324 rows x 2 columns]
#
# Middle Demand Skills:
#                                     Skill   Demand Level
# 63                'performance analysis']  Middle demand
# 82                         'log analysis'  Middle demand
# 131     'deliverability metrics analysis'  Middle demand
# 134                       'data analysis'  Middle demand
# 164                       'data analysis'  Middle demand
# ...

# %%
individual_skill = "test reporting"

# Convert the individual skill to a list for consistency
individual_skill_list = [individual_skill]

# Transform the individual skill using the same vectorizer
X_individual = vectorizer.transform(individual_skill_list)

# Predict the cluster for the individual skill
individual_skill_cluster = kmeans.predict(X_individual)[0]

# Determine the demand level for the individual skill
if individual_skill_cluster == highest_demand_cluster:
    demand_level = "High demand"
elif individual_skill_cluster == lowest_demand_cluster:
    demand_level = "Low demand"
else:
    demand_level = "Middle demand"

# Print the demand level for the individual skill
print(f"Skill: {individual_skill}, Demand Level: {demand_level}")
# Out:
# Skill: test reporting, Demand Level: Low demand

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import joblib

# Load your training data with tokenized skills
skills = training['tokenized_skills'].tolist()

# Feature extraction using TF-IDF
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(skills)

# Apply K-means clustering
n_clusters = 3  # Define the number of clusters
kmeans = KMeans(n_clusters=n_clusters)
kmeans.fit(X)

# Save the trained model and vectorizer
joblib.dump(vectorizer, 'tfidf_vectorizer1.joblib')
joblib.dump(kmeans, 'kmeans_model1.joblib')
# Out:
# /home/dell/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ['kmeans_model1.joblib']

# %%
#https://www.kaggle.com/discussions/getting-started/152295
# Head back to the original DataFrame (job_description.ipynb)

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.mixture import GaussianMixture

# Sample skill data
skills = [
    ['social media platforms', 'content creation', 'and scheduling', 'social media', 'community engagement', 'paid social advertising'],
    ['html', 'css', 'javascript', 'frontend frameworks', 'user experience ux'],
    ['quality control processes and methodologies', 'statistical process control', 'spc root', 'cause analysis and corrective', 'quality management systems eg', 'regulatory knowledge'],
    ['wireless network design', 'wifi standards and protocols', 'rf radio frequency', 'and optimization', 'wireless security protocols', 'troubleshooting', 'wireless network issues'],
    ['event planning', 'conference logistics', 'budget management', 'vendor coordination', 'marketing and promotion', 'client relations'],
    ['ui design', 'graphic design', 'adobe photoshop', 'typography and color theory', 'visual design and layout', 'responsive design'],
    ['account management', 'client relations', 'marketing strategies', 'campaign optimization', 'data analysis', 'communication skills'],
    ['product innovation', 'prototype development'],
    ['test automation', 'test framework development']
]

# Flatten the list of skills
flattened_skills = [skill for sublist in skills for skill in sublist]

# Feature extraction using TF-IDF
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(flattened_skills)

# Apply Gaussian Mixture Model clustering
n_components = 9  # Define the number of components (clusters)
gmm = GaussianMixture(n_components=n_components)
gmm.fit(X.toarray())

# Predict the cluster for each skill
skill_clusters = gmm.predict(X.toarray())

# Map cluster labels to demand levels
cluster_labels = {
    0: "High demand",
    1: "Low demand",
    2: "Middle demand"
}

# Initialize lists to store skills and demand levels
skills_list = []
demand_levels_list = []

# Map cluster predictions to demand levels
for skill, cluster in zip(flattened_skills, skill_clusters):
    skills_list.append(skill)
    demand_levels_list.append(cluster_labels[cluster])

# Create the DataFrame with additional columns
demand_df = pd.DataFrame({'Skill': skills_list, 'Demand Level': demand_levels_list})

# Display the DataFrame containing skills and their demand levels
print(demand_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[248], line 48
#      46 for skill, cluster in zip(flattened_skills, skill_clusters):
#      47     skills_list.append(skill)
# ---> 48     demand_levels_list.append(cluster_labels[cluster])
#      50 # Create the DataFrame with additional columns
#      51 demand_df = pd.DataFrame({'Skill': skills_list, 'Demand Level': demand_levels_list})
#
# KeyError: 3

# %%
from sklearn.metrics import silhouette_score


silhouette_avg = silhouette_score(X.toarray(), skill_clusters)
print("Silhouette Score:", silhouette_avg)
# Out:
# Silhouette Score: 0.0686567601830125
